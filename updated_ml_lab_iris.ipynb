# %% [markdown]
# # Machine Learning Lab: Iris Dataset
#
# This notebook explores three fundamental supervised and unsupervised learning algorithms:
#
# - **K-Means Clustering**
# - **Support Vector Machines (SVM)**
# - **Decision Trees**
#
# The dataset used is the classic Iris dataset, containing features of flower measurements.

# %% [markdown]
# ## K-Means Clustering (Unsupervised Learning)
#
# K-Means aims to partition data into **K clusters** by minimizing within-cluster variance.
#
# ### Objective Function:
# $$
# J = \sum_{i=1}^{K} \sum_{x \in C_i} ||x - \mu_i||^2
# $$
#
# Where:
# - $C_i$ = cluster i
# - $\mu_i$ = centroid of cluster i
#
# ### Steps:
# 1. Initialize centroids
# 2. Assign points to nearest centroid
# 3. Update centroids
# 4. Repeat until convergence

# %% [markdown]
# ## Support Vector Machine (SVM)
#
# SVM finds a hyperplane that maximizes the margin between classes.
#
# ### Decision Function:
# $$
# f(x) = w^T x + b
# $$
#
# ### Optimization Objective:
# $$
# \min_{w,b} \frac{1}{2}||w||^2
# $$
# subject to:
# $$
# y_i(w^T x_i + b) \geq 1
# $$
#
# ### Key Idea:
# Maximize margin between support vectors.

# %% [markdown]
# ## Decision Trees
#
# Decision Trees split data based on feature values.
#
# ### Entropy:
# $$
# H(S) = - \sum p_i \log_2 p_i
# $$
#
# ### Information Gain:
# $$
# IG = H(S) - \sum \frac{|S_v|}{|S|} H(S_v)
# $$
#
# Where:
# - $S$ = dataset
# - $S_v$ = subset after split
#
# ### Key Idea:
# Choose splits that maximize information gain.

# %% [markdown]
# # ML Lab: K-Means, SVM, Decision Tree (Iris Dataset)
# This lab prints outputs for autograder testing.

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# Load dataset
iris = datasets.load_iris()
X = iris.data
y = iris.target

print("DATASET_SHAPE:", X.shape, y.shape)

# %%
# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

print("TRAIN_TEST_SPLIT:", X_train.shape, X_test.shape)

# %%
# K-Means Clustering
kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)
kmeans.fit(X_train)

kmeans_labels = kmeans.predict(X_test)

print("KMEANS_CENTERS:", kmeans.cluster_centers_)
print("KMEANS_LABELS_SAMPLE:", kmeans_labels[:10])

# %%
# SVM Classifier
svm = SVC(kernel='linear', random_state=42)
svm.fit(X_train, y_train)

svm_preds = svm.predict(X_test)
svm_acc = accuracy_score(y_test, svm_preds)

print("SVM_ACCURACY:", round(svm_acc, 4))
print("SVM_PRED_SAMPLE:", svm_preds[:10])

# %%
# Decision Tree Classifier
dt = DecisionTreeClassifier(random_state=42)
dt.fit(X_train, y_train)

dt_preds = dt.predict(X_test)
dt_acc = accuracy_score(y_test, dt_preds)

print("DT_ACCURACY:", round(dt_acc, 4))
print("DT_PRED_SAMPLE:", dt_preds[:10])
